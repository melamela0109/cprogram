// %% [markdown]
// 25문// 코드 채우기 // 계산하기(2진법 16진법 변환)
// 1장 >> 확인문제 (책) 요약 풀어보기
// 2장 >> 중요 C프로그램 소스파일 헤더파일의 의미 어떤 용도로 헤더파일 사용하는지 함수들을 정의 헤더파일 전처리 확인문제 2장-2섹션 코드를 구성하는 기본요소 ** 5가지요소 그것이 무엇인지 의미 정확하게 파악
// 2진법, 16진법 2진법 3개 >> 8진법 10진수를 어떻게 바꾸는지/ 식별자를 만들 때 중요한 원칙 (예약어, 숫자, 특수문자_는 사용가능 어떻게 만드는지) 출력-제어 문자? 변환코드 뭐가 있는지. 어떻게 활용?
// 3장 >> 메모리 데이터 타입 타입 한정자 const type_definition 활용 (**시험) 어떤 내용을 별칭으로 만들고 싶어 signed char unsigned char 오버플로우 언더플로우 어떻게 값이 변하는지?(char만 하면됨 long이랑 그런건 x) 데이터 타입 구분 이유는 메모리를 위해서 (효율) float형 지수부 가수부 비트손실 / 문자 (아스키코드) utf-8 파일 1~4바이트 (문자) 한글 3바이트 이모지 특수문자 4바이트
// 4장 >> 표현식 확인문제 증감연산자 전위 후위 연산자 부정 /논리곱, 논리합 연산자 (어떤식으로 논리곱, 논리합을 활용하는지) 비트 시프트 했을 때 값들이 어떻게 변화 삼항연산자 이용해서 어떤 것을 구현(1문제)
// 5장 >> IF 문 >> SWITCH문 바꾸는거  어떻게 서로 상호 변환가능하는지 SWITCH문의 특징 (반드시 BREAK문 사용)
// 6장 >> FOR문 >> WHILE문 으로 바꾸는거
// 팩토리얼 관련 문제 (팩토리얼 만드는 방법)(1문)
// 7장 >> 다차원배열(1문) 배열의 크기와 길이 (1문)
